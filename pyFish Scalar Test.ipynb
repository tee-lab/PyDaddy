# %% [markdown]
# # Import Modules

# %%
import pyFish
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Sample data
# > Comment second line for pairwise data

# %%
data = np.loadtxt('data/pairwise/TimeSeries/TimeSeries_pairwise_N_50_.csv', delimiter=',')
#data = np.loadtxt('data/ternary/TimeSeries/TimeSeries_ternary_N_50_.csv', delimiter=',')
X = data[:,0]
t = data[:,1]
t_int = t[-1]/len(t)

# %% [markdown]
# # Initialize object with parameters

# %%
sde = pyFish.Characterize(inc=0.01, t_lag=1000, simple_method=True, max_order=10, delta_t=1)

# %% [markdown]
# # Analyse

# %%
out = sde([X],t, dt='auto')
out

# %%
drift, diff, avgdrift, avgdiff, op = out.data()
len(diff), len(drift),len(avgdrift), len(avgdiff), len(op)
# Out:
# (100000, 99952, 200, 200, 200)

# %% [markdown]
# # View parameters

# %%
out.parameters()
# Out:
# {'t_lag': 1000,
#  'simple_method': True,
#  'max_order': 10,
#  'inc': 0.01,
#  'dt_': 'auto',
#  'delta_t': 1,
#  'vector': False,
#  't_int': 0.999990000099999,
#  'autocorrelation_time': 49.835703894504334,
#  'drift_order': 1,
#  'diff_order': 2,
#  'dt': 49}

# %% [markdown]
# # Visualize Output

# %%
out.visualize()

# %% [markdown]
# # Diagnostics graphs

# %%
 out.diagnostic()
