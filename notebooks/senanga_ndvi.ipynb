# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append('..')

# %%
import pyFish
# Out:
# ZMQInteractiveShell

# %%
data_ndvi = pd.read_csv('senanga_ndvi.csv')

# %%
data_ndvi
# Out:
#      time_step          date     ndvi
# 0            1  Feb 18, 2000  5475.32
# 1            2   Mar 5, 2000  4495.30
# 2            3  Mar 21, 2000  5412.86
# 3            4   Apr 6, 2000  5313.11
# 4            5  Apr 22, 2000  5243.54
# ..         ...           ...      ...
# 475        476  Oct 15, 2020  4230.61
# 476        477  Oct 31, 2020  4434.77
# 477        478  Nov 16, 2020  4712.71
# 478        479   Dec 2, 2020  5384.44
# 479        480  Dec 18, 2020  5606.33
#
# [480 rows x 3 columns]

# %%
X = data_ndvi['ndvi'].to_numpy()
t = data_ndvi['time_step'].to_numpy()

# %%
plt.plot(t,X)

# %%
len(X)
# Out:
# 480

# %%
ch = pyFish.Characterize([X], t=t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8766fd49339b> in <module>
# ----> 1 ch = pyFish.Characterize([X], t=t)
#
# ~/Documents/Schooling_Fish/package/git_hub/pyFish/pyFish/__main__.py in __new__(cls, data, t, dt, delta_t, t_lag, inc, inc_x, inc_y, max_order, fft, drift_order, diff_order, order_metric, n_trials, n_dt, **kwargs)
#     320                         inc_y=inc_y,
#     321                         t_lag=t_lag,
# --> 322                         max_order=max_order,
#     323 		)
#
# ~/Documents/Schooling_Fish/package/git_hub/pyFish/pyFish/__main__.py in __call__(self, data, t, dt, inc, inc_x, inc_y, t_lag, max_order, simple_method, **kwargs)
#     157                                                                                    max_order=self.max_order,
# ...
