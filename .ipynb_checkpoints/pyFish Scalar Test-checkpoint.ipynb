# %% [markdown]
# # Import Modules

# %%
import pyFish
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Sample data
# > Comment second line for pairwise data
#
# > Uncomment 3rd line for vegetation data (Shuaib's data)

# %%
data = np.loadtxt('data/pairwise/TimeSeries/TimeSeries_pairwise_N_50_.csv', delimiter=',')
data = np.loadtxt('data/ternary/TimeSeries/TimeSeries_ternary_N_50_.csv', delimiter=',')
#data = np.loadtxt('data/extras/data.txt')
X = data[:,0]
t = data[:,1]
t_int = t[-1]/len(t)

# %% [markdown]
# # Initialize object with parameters
# ### Default parameter values:
# 			dt='auto',
# 			delta_t =1,
# 			t_int=None,
# 			t_lag=1000,
# 			inc=0.01,
# 			inc_x=0.1,
# 			inc_y=0.1,
# 			max_order=10,
# 			fft = True,
# 			drift_order = None,
# 			diff_order = None,
# 			order_metric = "R2_adj",
# 			simple_method = True,
# 			n_trials = 1,

# %% [markdown]
# # Analyse

# %%
out = pyFish.Characterize(data=[X],t=t)
out
# Out:
# Gaussian check for underlying noise: 100%|██████████| 10000/10000 [00:00<00:00, 19655.19it/s]

# %%
drift, diff, avgdrift, avgdiff, op = out.data()
len(diff), len(drift),len(avgdrift), len(avgdiff), len(op)
# Out:
# (100000, 99993, 200, 200, 200)

# %% [markdown]
# # View parameters

# %%
out.parameters()
# Out:
# {'dt_': 'auto',
#  't_int': '0.999990000099999',
#  't_lag': '1000',
#  'simple_method': 'True',
#  'max_order': '10',
#  'inc': '0.01',
#  'inc_x': '0.1',
#  'inc_y': '0.1',
#  'delta_t': '1',
#  'order_metric': 'R2_adj',
#  'fft': 'True',
#  'drift_order': '3',
#  'diff_order': '2',
#  'n_trials': '1',
#  'vector': 'False',
#  'autocorrelation_time': '78.80827753926768',
#  'dt': '8',
#  'gaussian_noise': 'True',
#  'k': '1.1581548969877782',
#  'l_lim': '-74.73437749480917',
#  'h_lim': '75.76449030456274'}

# %% [markdown]
# # Visualize Output

# %%
out.visualize()

# %% [markdown]
# # Diagnostics graphs

# %%
 out.diagnostic()

# %% [markdown]
# # Noise Characterstics

# %%
out.noise_characterstics()
# Out:
# Noise is gaussian
