# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyFish
pyFish.__version__
# Out:
# '1.0'

# %%
Mx_2, My_2 = np.loadtxt('syn_pairwise.txt').T
Mx_3, My_3 = np.loadtxt('syn_ternary.txt').T
time_step_2 = np.arange(0, len(Mx_2)*0.12, 0.12)
time_step_3 = np.arange(0, len(Mx_3)*0.12, 0.12)

# %%
import pyFish
print(pyFish.__version__)
ch_2 = pyFish.Characterize([Mx_2, My_2], t=0.12)
# Out:
# 1.1
# opt_dt
# drift diff
# Generating Slider data: 100%|██████████| 8/8 [00:19<00:00,  2.46s/it]
# <div>
#
#
#             <div id="6b189065-0a1a-4c86-941c-d8260d51ac55" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b189065-0a1a-4c86-941c-d8260d51ac55")) {
#                     Plotly.newPlot(
#                         '6b189065-0a1a-4c86-941c-d8260d51ac55',
# ...

# %%
ch_2.parameters()
# Out:
# {'dt_': 'auto',
#  'res_dir': '2021-01-19 10:19:47',
#  't_lag': '1000',
#  'max_order': '10',
#  'inc': '0.01',
#  'inc_x': '0.1',
#  'inc_y': '0.1',
#  'delta_t': '1',
#  'order_metric': 'R2_adj',
#  'fft': 'True',
#  'drift_order': '1',
#  'diff_order': '2',
#  'n_trials': '1',
#  'n_dt': '8',
#  'vector': 'True',
#  't_int': '0.12',
#  'autocorrelation_time': '13.330889514008469',
#  'dt': '13',
#  'gaussian_noise': 'True',
#  'k': '-2.6280639153146907',
#  'l_lim': '-209.5832257221993',
#  'h_lim': '149.5336467469141'}
